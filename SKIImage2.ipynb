# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi
from skimage import feature
import cv2

image=np.load("E://Rapid-FLIM_Polymer2//PE-LD/PE-LD_M39_RF170.npy")
image =image[0,:,:]
image = cv2.GaussianBlur(image, (9, 9), 0)
# image = ndi.gaussian_filter(image,1, order=0)

edges =[]

for i in [0.25*i for i in range(1,16)]:
    edges.append(feature.canny(image, sigma=i))

fig, axes = plt.subplots(figsize=(15,12),nrows=3, ncols=5, sharex=True, sharey=True)
for i in range(15):
    axes.flat[i].imshow(edges[i],cmap=plt.cm.gray)
    axes.flat[i].set_axis_off()
    axes.flat[i].set_title("Sigma = {}".format(0.25*i),fontsize=16)
fig.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7868\24717262.py in <module>
#      20     axes.flat[i].set_axis_off()
#      21     axes.flat[i].set_title("Sigma = {}".format(0.25*i),fontsize=16)
# ---> 22     contours, hierarchies = cv2.findContours(edges, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      23     print(f'{len(contours)} contour(s) found..!')
#      24 fig.tight_layout()
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'findContours'
# > Overload resolution failed:
# >  - image is not a numpy array, neither a scalar
# >  - Expected Ptr<cv::UMat> for argument 'image'
