# %%
import numpy as np
import cv2
import argparse
import matplotlib.pyplot as plt
from PIL import Image
arr=np.load('D:\\numpy_files\\ABS\\ABS_M01_RF000.npy')
img=arr[0:,:]

kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img, -1, kernelx)
img_prewitty = cv2.filter2D(img, -1, kernely)
add =img_prewittx + img_prewitty
# cv2.imshow("Prewitt X", img_prewittx)
# cv2.imshow("Prewitt Y", img_prewitty)
# cv2.imshow("Prewitt", img_prewittx + img_prewitty)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24032\3146431177.py in <module>
#       9 kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
#      10 kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
# ---> 11 img_prewittx = cv2.filter2D(img, -1, kernelx)
#      12 img_prewitty = cv2.filter2D(img, -1, kernely)
#      13 add =img_prewittx + img_prewitty
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\matrix.cpp:1099: error: (-215:Assertion failed) dims <= 2 && step[0] > 0 in function 'cv::Mat::locateROI'

# %%
plt.figure(figsize=(16, 5))
plt.subplot(131)
plt.imshow(img_prewittx, cmap=plt.cm.gray)
plt.axis('off')
plt.title('Prewitt X', fontsize=20)
plt.subplot(132)
plt.imshow(img_prewitty,cmap=plt.cm.gray)
plt.axis('off')
plt.title('Prewitt Y', fontsize=20)
plt.subplot(133)
plt.imshow(add ,cmap=plt.cm.gray)
plt.axis('off')
plt.title('add', fontsize=20)


# im += 0.07*np.random.random(im.shape)

# sx = ndimage.sobel(im, axis=0, mode='constant')
# sy = ndimage.sobel(im, axis=1, mode='constant')
# sob = np.hypot(sx, sy)





plt.subplots_adjust(wspace=0.02, hspace=0.02, top=1, bottom=0, left=0, right=0.9)

plt.show()
